# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5244, 3081, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'originated', 'anarchism', 'term', 'as', 'originated', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.190382
# Nearest to an: hurling, ascension, sanguine, richardson, mathews, prophecies, bottoms, quelled,
# Nearest to would: gigahertz, pharisees, impurity, covens, ewes, bova, beautiful, spares,
# Nearest to time: veda, bckgr, italian, subtree, paraguayan, morpheus, selectable, mercantilist,
# Nearest to system: joab, cogency, harman, breed, kournikova, ethiopic, helmholtz, contarini,
# Nearest to such: scrabble, heavier, drusilla, exec, temper, pedestal, trusted, sacramental,
# Nearest to not: advises, reassignment, nsfnet, canadiens, manipulation, barricade, honshu, humanist,
# Nearest to his: ishvara, hitomaro, proliferation, lost, lascaux, egalitarian, radars, seine,
# Nearest to over: discontinuous, esb, isomers, trunk, foreshadow, partridge, mauritania, julie,
# Nearest to also: kimberly, retitled, raging, karin, coolest, appreciate, pooh, stemming,
# Nearest to when: loathing, cavalcanti, labrador, ramen, reintroduction, handlebars, slovakian, restructured,
# Nearest to a: equivalent, individualism, sofia, ours, immediacy, hn, purified, dissemination,
# Nearest to than: saddam, nose, steward, catered, toshiba, spenser, woolen, rouse,
# Nearest to use: disorderly, seasonally, expletive, beatles, manganese, dynamical, akad, springfield,
# Nearest to this: deutsches, whitepapers, unquestionably, icing, liberia, tla, trumpeter, keyser,
# Nearest to as: shamanistic, impasse, oireachtas, monotonic, beavis, battery, bootlegged, seyss,
# Nearest to more: drugs, erection, mudslides, gary, starbucks, anhydrous, analyst, consanguinity,
# Average loss at step 2000: 4.366640
# Average loss at step 4000: 3.864535
# Average loss at step 6000: 3.794229
# Average loss at step 8000: 3.693061
# Average loss at step 10000: 3.621277
# Nearest to an: the, prophecies, hammerheads, posting, christa, sightseeing, qos, emedicine,
# Nearest to would: will, could, can, must, autocode, may, should, ceo,
# Nearest to time: veda, morpheus, subtree, bckgr, individuals, italian, rosalyn, generally,
# Nearest to system: kournikova, joab, witted, fayette, poindexter, harman, superlatives, contarini,
# Nearest to such: scrabble, temper, heavier, well, psychotic, waterfalls, swim, pedestal,
# Nearest to not: it, only, also, there, still, to, advises, carpetbaggers,
# Nearest to his: their, its, the, s, her, conditioned, a, softer,
# Nearest to over: isomers, discontinuous, foreshadow, specialises, ground, austrofascism, proved, manpower,
# Nearest to also: not, there, parliaments, glamour, which, climbs, gtpase, bourke,
# Nearest to when: although, satisfactorily, hit, spent, cavalcanti, me, compressing, amusing,
# Nearest to a: the, nos, this, redesigned, swell, density, his, no,
# Nearest to than: genomes, nose, steward, rouse, saddam, keller, intolerable, wollheim,
# Nearest to use: macromedia, ibo, pneumatic, discourses, serial, complimentary, universelle, end,
# Nearest to this: it, the, nihilist, which, a, procopius, ooze, that,
# Nearest to as: usurpation, microkernels, refinery, by, seyss, bootleg, lipoproteins, washed,
# Nearest to more: gobi, hydroelectric, anonymously, gary, ascalon, telekom, rangle, physiologist,
# Average loss at step 12000: 3.605390
# Average loss at step 14000: 3.565412
# Average loss at step 16000: 3.409377
# Average loss at step 18000: 3.462651
# Average loss at step 20000: 3.539940
# Nearest to an: prophecies, hammerheads, sightseeing, aerodynamics, the, roux, propped, style,
# Nearest to would: will, could, can, must, may, should, might, but,
# Nearest to time: individuals, veda, tighter, morpheus, rosalyn, poison, investigated, andes,
# Nearest to system: joab, kournikova, superlatives, witted, fayette, detonates, dte, causeway,
# Nearest to such: well, scrabble, known, temper, waterfalls, other, both, many,
# Nearest to not: only, also, still, they, it, to, there, vasco,
# Nearest to his: their, its, her, the, conditioned, pelias, some, imperfection,
# Nearest to over: ground, specialises, isomers, discontinuous, austrofascism, frankish, foreshadow, incalculable,
# Nearest to also: which, not, there, still, often, now, usually, sometimes,
# Nearest to when: was, if, after, although, that, fencers, regarding, additionally,
# Nearest to a: the, this, any, gauguin, nos, huffman, no, redesigned,
# Nearest to than: nose, or, intolerable, genomes, heifer, monroe, keller, rhine,
# Nearest to use: end, know, greatest, ibo, discourses, complimentary, sui, arians,
# Nearest to this: it, which, the, toland, eraser, their, what, nihilist,
# Nearest to as: seyss, cerebellum, irishman, usurpation, historicist, graphically, aj, filament,
# Nearest to more: gobi, greater, most, very, less, rather, commission, hydroelectric,
# Average loss at step 22000: 3.506212
# Average loss at step 24000: 3.491827
# Average loss at step 26000: 3.486922
# Average loss at step 28000: 3.478108
# Average loss at step 30000: 3.507448
# Nearest to an: hammerheads, sightseeing, prophecies, hurling, the, novoselic, cybernetic, aerodynamics,
# Nearest to would: could, will, can, should, may, must, might, to,
# Nearest to time: tighter, veda, individuals, morpheus, rosalyn, romans, year, basalt,
# Nearest to system: witted, kournikova, detonates, superlatives, novas, postgraduate, endothermic, modulation,
# Nearest to such: well, known, waterfalls, other, these, psychotic, yea, scrabble,
# Nearest to not: they, only, still, it, also, generally, vasco, crewmen,
# Nearest to his: their, her, its, the, s, our, conditioned, sourcebook,
# Nearest to over: specialises, ground, unceasing, discontinuous, unchanged, manhattan, austrofascism, isomers,
# Nearest to also: now, often, sometimes, boulevard, still, demo, who, which,
# Nearest to when: after, if, although, before, while, during, where, but,
# Nearest to a: any, regarded, no, winger, mountaineer, usda, assignments, the,
# Nearest to than: nose, genomes, heifer, monroe, keller, rhine, gahan, intolerable,
# Nearest to use: end, sui, greatest, essen, know, executives, disorderly, ibo,
# Nearest to this: it, which, what, ooze, sideband, there, any, akimbo,
# Nearest to as: by, aj, restraint, cerebellum, sino, or, ancyra, lynch,
# Nearest to more: less, most, gobi, very, greater, rather, commission, hydroelectric,
# Average loss at step 32000: 3.502060
# Average loss at step 34000: 3.501331
# Average loss at step 36000: 3.454748
# Average loss at step 38000: 3.301368
# Average loss at step 40000: 3.433388
# Nearest to an: hammerheads, aerodynamics, sightseeing, ascension, entendre, cytotoxic, interpreting, prophecies,
# Nearest to would: will, could, can, may, should, must, might, did,
# Nearest to time: tighter, way, year, veda, day, period, romans, basalt,
# Nearest to system: witted, systems, dispositions, kournikova, homesick, causeway, type, knud,
# Nearest to such: well, known, these, including, yea, waterfalls, described, temper,
# Nearest to not: it, still, they, only, generally, never, kore, also,
# Nearest to his: her, their, its, the, our, your, s, conditioned,
# Nearest to over: ced, proved, understandable, ground, about, unchanged, from, barcodes,
# Nearest to also: often, now, which, sometimes, still, usually, boulevard, demo,
# Nearest to when: if, before, after, where, while, although, during, additionally,
# Nearest to a: the, any, praetorians, or, rijeka, prefectures, sundays, cinematographers,
# Nearest to than: or, nose, sloop, genomes, monroe, heifer, rhine, much,
# Nearest to use: know, end, provide, ibo, classes, question, sui, executives,
# Nearest to this: which, it, the, that, any, ooze, another, diophantine,
# Nearest to as: cerebellum, psychosocial, ideologically, microkernels, restraint, depopulated, aching, replied,
# Nearest to more: less, most, very, greater, increasingly, rather, gobi, higher,
# Average loss at step 42000: 3.434645
# Average loss at step 44000: 3.454165
# Average loss at step 46000: 3.452268
# Average loss at step 48000: 3.351944
# Average loss at step 50000: 3.384093
# Nearest to an: the, sightseeing, propped, hammerheads, prophecies, interpreting, hurling, bien,
# Nearest to would: could, will, can, may, must, should, might, cannot,
# Nearest to time: year, way, tighter, period, day, portrayal, veda, forehead,
# Nearest to system: systems, dispositions, witted, breed, novas, stretch, modulation, concedes,
# Nearest to such: well, known, these, yea, including, described, many, psychotic,
# Nearest to not: kore, they, generally, still, usually, it, crewmen, scorched,
# Nearest to his: her, their, its, the, my, your, conditioned, whose,
# Nearest to over: about, through, ced, anhui, specialises, lincoln, connectors, incalculable,
# Nearest to also: often, which, sometimes, now, who, still, arabized, frequently,
# Nearest to when: while, after, if, before, during, where, although, but,
# Nearest to a: any, the, another, nos, no, bankruptcy, gauguin, moot,
# Nearest to than: or, sloop, much, heifer, dahl, comply, genomes, slight,
# Nearest to use: end, most, form, astrological, know, order, greatest, classes,
# Nearest to this: which, it, the, sideband, he, toland, another, that,
# Nearest to as: cerebellum, restraint, historicist, seyss, usurpation, bfi, became, by,
# Nearest to more: less, most, very, greater, increasingly, rather, cody, higher,
# Average loss at step 52000: 3.434929
# Average loss at step 54000: 3.428585
# Average loss at step 56000: 3.437811
# Average loss at step 58000: 3.397253
# Average loss at step 60000: 3.398161
# Nearest to an: sightseeing, hurling, hammerheads, roux, cytotoxic, prophecies, cybernetic, propped,
# Nearest to would: will, could, can, may, must, should, might, cannot,
# Nearest to time: period, way, year, forehead, cases, tighter, interfaces, day,
# Nearest to system: systems, witted, dispositions, stretch, design, type, kournikova, breed,
# Nearest to such: well, known, these, yea, including, certain, many, described,
# Nearest to not: still, kore, usually, generally, they, crewmen, reissued, ignaz,
# Nearest to his: her, their, its, my, your, the, our, conditioned,
# Nearest to over: through, around, about, ced, specialises, within, eraser, incalculable,
# Nearest to also: now, often, still, sometimes, who, usually, demo, which,
# Nearest to when: if, while, after, although, where, though, before, however,
# Nearest to a: any, another, every, the, awake, prefectures, this, praetorians,
# Nearest to than: or, but, much, comply, and, dahl, sloop, genomes,
# Nearest to use: classes, form, most, know, end, nature, reason, practice,
# Nearest to this: which, it, that, there, the, what, some, however,
# Nearest to as: historicist, geologists, cerebellum, sorbonne, when, wyche, pulling, balm,
# Nearest to more: less, most, increasingly, rather, very, greater, higher, rhein,
# Average loss at step 62000: 3.241806
# Average loss at step 64000: 3.254904
# Average loss at step 66000: 3.404541
# Average loss at step 68000: 3.396617
# Average loss at step 70000: 3.359870
# Nearest to an: sightseeing, hammerheads, raphael, mauritius, osbourne, bien, the, interpreting,
# Nearest to would: will, could, may, can, must, should, might, cannot,
# Nearest to time: period, tighter, way, forehead, interfaces, veda, year, authority,
# Nearest to system: systems, process, design, aleksandr, holley, witted, dispositions, modulation,
# Nearest to such: well, these, known, certain, including, many, hasmonaean, yea,
# Nearest to not: still, generally, always, usually, never, now, encased, reissued,
# Nearest to his: her, their, its, my, your, whose, our, him,
# Nearest to over: through, about, around, eraser, shamrock, specialises, ced, across,
# Nearest to also: now, often, sometimes, still, which, arabized, usually, below,
# Nearest to when: if, while, after, however, though, where, before, although,
# Nearest to a: the, another, any, palmyra, enough, this, huffman, prefectures,
# Nearest to than: but, comply, or, no, sloop, and, much, dahl,
# Nearest to use: form, most, end, know, cause, keeping, nurtured, identify,
# Nearest to this: which, it, the, there, some, that, another, what,
# Nearest to as: usurpation, cerebellum, restraint, marsupials, when, daigo, balm, outdoor,
# Nearest to more: less, most, very, increasingly, rather, higher, cody, highly,
# Average loss at step 72000: 3.374872
# Average loss at step 74000: 3.352755
# Average loss at step 76000: 3.317226
# Average loss at step 78000: 3.352094
# Average loss at step 80000: 3.377123
# Nearest to an: sightseeing, hammerheads, bien, propped, raphael, osbourne, ascension, cytotoxic,
# Nearest to would: will, could, may, can, must, should, might, cannot,
# Nearest to time: year, ally, tighter, interval, rosalyn, period, printings, forehead,
# Nearest to system: systems, process, program, witted, modulation, holley, dispositions, aleksandr,
# Nearest to such: well, known, these, including, certain, yea, hasmonaean, seen,
# Nearest to not: still, always, generally, actually, usually, now, reissued, they,
# Nearest to his: her, their, its, my, your, our, the, whose,
# Nearest to over: through, around, about, across, frankish, ced, between, shamrock,
# Nearest to also: now, sometimes, often, still, which, usually, never, boulevard,
# Nearest to when: after, if, before, while, during, although, though, where,
# Nearest to a: the, gauguin, any, another, every, moot, swell, huffman,
# Nearest to than: much, dahl, or, comply, sloop, but, even, freshness,
# Nearest to use: form, most, cause, list, display, checksum, because, support,
# Nearest to this: which, it, there, the, judas, itself, another, some,
# Nearest to as: cerebellum, spielberg, usurpation, annuals, aj, pipelining, when, discusses,
# Nearest to more: less, most, very, increasingly, rather, higher, larger, cody,
# Average loss at step 82000: 3.410002
# Average loss at step 84000: 3.411552
# Average loss at step 86000: 3.388901
# Average loss at step 88000: 3.354958
# Average loss at step 90000: 3.367618
# Nearest to an: sightseeing, propped, hammerheads, hurling, raphael, bien, ascension, dakuten,
# Nearest to would: could, will, might, can, may, must, should, did,
# Nearest to time: tighter, period, way, before, year, dignified, authority, veda,
# Nearest to system: systems, process, holley, program, conceal, line, ned, strategy,
# Nearest to such: well, known, these, yea, certain, including, monogatari, psychotic,
# Nearest to not: still, always, nor, now, actually, generally, it, occasionally,
# Nearest to his: her, their, its, my, your, our, whose, the,
# Nearest to over: through, around, about, frankish, within, across, specialises, shamrock,
# Nearest to also: now, often, sometimes, still, which, who, never, usually,
# Nearest to when: after, before, if, while, where, although, during, until,
# Nearest to a: any, every, praetorians, another, the, usda, bottleneck, moot,
# Nearest to than: dahl, comply, much, sloop, no, even, bowman, aggregated,
# Nearest to use: descendants, most, practice, checksum, crimean, list, addition, attendances,
# Nearest to this: it, which, the, some, diophantine, itself, another, judas,
# Nearest to as: cerebellum, mccullough, sorbonne, outdoor, usurpation, grotius, including, costumed,
# Nearest to more: less, very, increasingly, most, rather, larger, highly, greater,
# Average loss at step 92000: 3.398305
# Average loss at step 94000: 3.256419
# Average loss at step 96000: 3.361452
# Average loss at step 98000: 3.241166
# Average loss at step 100000: 3.362247
# Nearest to an: sightseeing, hurling, another, bien, novoselic, the, raphael, prophecies,
# Nearest to would: could, will, might, can, may, should, must, did,
# Nearest to time: way, period, tighter, portrayal, dignified, year, day, synonymously,
# Nearest to system: systems, process, program, holley, witted, ned, aleksandr, triode,
# Nearest to such: well, known, these, including, certain, yea, many, seen,
# Nearest to not: never, always, still, nor, now, actually, generally, they,
# Nearest to his: her, their, my, your, its, our, the, s,
# Nearest to over: around, about, through, across, within, onto, shamrock, considerable,
# Nearest to also: sometimes, now, still, often, never, usually, who, laureates,
# Nearest to when: if, while, before, although, after, where, though, during,
# Nearest to a: any, another, the, swell, assignments, prefectures, moot, palmyra,
# Nearest to than: or, much, dahl, comply, even, sloop, no, slightly,
# Nearest to use: form, cause, most, descendants, checksum, list, practice, rest,
# Nearest to this: it, which, topaz, itself, another, that, what, there,
# Nearest to as: usurpation, when, cerebellum, mccullough, seyss, balm, although, restraint,
# Nearest to more: less, very, most, rather, larger, increasingly, highly, greater,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# The model proposed is such simple in getting contexts so we can just swap labels and inputs to get CBOW analogy

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        # WOW SUCH CBOW
        batch_labels, batch_data = generate_batch(batch_size, num_skips, skip_window)
        batch_data = batch_data.reshape((batch_size,))
        batch_labels = batch_labels.reshape((batch_size, 1))
        
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From c:\miniconda3\envs\tensorflow\lib\site-packages\tensorflow\python\util\tf_should_use.py:170: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 7.886938
# Nearest to an: biome, aed, fighter, empresses, torre, hammersmith, maximise, chemically,
# Nearest to would: valves, productivity, cancels, sulba, invitational, earmarked, franchise, disowned,
# Nearest to time: banquo, funeral, rodent, gokturks, pressed, glasnost, dhamma, canopy,
# Nearest to system: cayley, denning, hike, booster, cardinality, provincial, footsteps, rhetorician,
# Nearest to such: deist, outlets, creators, codata, roundabout, edith, eastern, prose,
# Nearest to not: gould, mosque, marvin, merseyside, finlandization, motorized, batavia, culminating,
# Nearest to his: paragraph, hpv, constitutional, roping, agnes, shing, vast, firmly,
# Nearest to over: acclaimed, informative, antiprism, retarded, katha, achaeans, alabama, shoulder,
# Nearest to also: brink, zs, brackish, secundus, wye, maclisp, bottlenecks, nets,
# Nearest to when: markedly, thermally, herrera, landslide, fmd, enlarging, urinate, heuss,
# Nearest to a: lux, piloting, lugo, clausius, jurists, sunglasses, ussr, chapels,
# Nearest to than: wetland, convict, oe, guarantees, ursidae, breisgau, pulsation, aztecs,
# Nearest to use: orchid, apok, sanctuaries, rhys, auditioned, provencal, holstein, musings,
# Nearest to this: immunology, aleksander, muscular, gernsback, carolinas, kali, ghanaian, mosquitia,
# Nearest to as: psychotherapist, technology, moa, prophesied, perennially, wyclif, rooftop, painter,
# Nearest to more: bertolucci, recovered, transgender, linehan, aleksander, cannibalistic, consist, artworks,
# Average loss at step 2000: 4.378780
# Average loss at step 4000: 3.875989
# Average loss at step 6000: 3.798706
# Average loss at step 8000: 3.762473
# Average loss at step 10000: 3.623157
# Nearest to an: piecewise, mathematicians, aed, differentiability, minesweeper, this, millennia, copycat,
# Nearest to would: must, may, will, can, sulba, should, disarming, productivity,
# Nearest to time: way, dhamma, topographical, sla, immunity, preparation, rabbani, kapitan,
# Nearest to system: minsky, vatican, cayley, provincial, denning, persisting, implementing, facilities,
# Nearest to such: these, well, creators, deist, codata, known, maranh, eastern,
# Nearest to not: merseyside, that, fenced, motorized, often, which, qazaqstan, it,
# Nearest to his: their, the, her, fructose, routed, s, adalbert, telephus,
# Nearest to over: positive, antiprism, achaeans, khuzestan, compulsion, full, skulls, worst,
# Nearest to also: often, which, cleves, maskhadov, who, still, gru, it,
# Nearest to when: however, enlarging, henotheistic, leveling, fmd, conqueror, fouls, dans,
# Nearest to a: the, transcribed, jurists, supplies, mascarenhas, teleplay, organisms, fatality,
# Nearest to than: wetland, pulsation, maneuvers, redirection, kazan, aztecs, convict, marketplace,
# Nearest to use: orchid, auditioned, amount, frg, fountains, descending, apollo, fgth,
# Nearest to this: which, it, that, the, what, each, muscular, ethologists,
# Nearest to as: psychotherapist, roamed, investments, orbiter, harboring, by, transplant, scenery,
# Nearest to more: bertolucci, larger, very, artworks, fraud, cannibalistic, milken, honestly,
# Average loss at step 12000: 3.586287
# Average loss at step 14000: 3.618578
# Average loss at step 16000: 3.585126
# Average loss at step 18000: 3.572874
# Average loss at step 20000: 3.548532
# Nearest to an: ludo, devoiced, millennia, legion, irreducible, piecewise, aed, jojo,
# Nearest to would: can, will, may, must, could, should, might, to,
# Nearest to time: way, preparation, topographical, gokturks, tort, idea, assimilate, smuts,
# Nearest to system: minsky, vatican, facilities, alone, eco, cayley, assertions, effects,
# Nearest to such: these, well, known, maranh, creators, many, limbic, other,
# Nearest to not: fenced, still, merseyside, they, usually, always, this, hayes,
# Nearest to his: their, her, its, the, s, this, adalbert, evolution,
# Nearest to over: positive, full, antiprism, featuring, skulls, worst, milos, giraffe,
# Nearest to also: often, still, never, which, now, cleves, who, minh,
# Nearest to when: if, after, where, since, enlarging, was, treasures, dans,
# Nearest to a: fayed, the, any, hugh, teleplay, jurists, charlton, vocal,
# Nearest to than: redirection, wetland, ursidae, maneuvers, posteriori, lyman, or, gaines,
# Nearest to use: amount, descending, genuine, orchid, frg, fountains, urls, form,
# Nearest to this: it, which, what, that, the, any, raspberry, denominational,
# Nearest to as: by, masculism, phoca, scenery, rolled, is, through, saeed,
# Nearest to more: less, most, very, larger, frelimo, other, seizures, ilium,
# Average loss at step 22000: 3.528386
# Average loss at step 24000: 3.441152
# Average loss at step 26000: 3.420721
# Average loss at step 28000: 3.475489
# Average loss at step 30000: 3.409020
# Nearest to an: millennia, devoiced, legion, redefining, commons, brahe, thrash, jojo,
# Nearest to would: will, can, may, could, must, should, might, does,
# Nearest to time: preparation, rodent, way, maxi, gokturks, putney, denominated, woodcut,
# Nearest to system: minsky, effects, vatican, magnet, tulare, fang, systems, devices,
# Nearest to such: these, well, known, maranh, regarded, exploitation, prosperity, daphne,
# Nearest to not: they, it, still, merseyside, usually, also, we, always,
# Nearest to his: their, her, its, the, adalbert, s, guns, evolution,
# Nearest to over: positive, full, skulls, featuring, algernon, module, from, around,
# Nearest to also: often, still, now, never, which, sometimes, who, hilly,
# Nearest to when: if, where, before, although, after, by, blurring, however,
# Nearest to a: the, no, fayed, accidents, jurists, teleplay, any, this,
# Nearest to than: or, much, bead, redirection, lyman, rafe, posteriori, wetland,
# Nearest to use: amount, descending, frg, orchid, apollo, fountains, genuine, fgth,
# Nearest to this: it, which, the, that, what, each, id, some,
# Nearest to as: is, phoca, objection, christoph, masculism, in, through, harmonicas,
# Nearest to more: less, most, very, larger, other, frelimo, chirality, longer,
# Average loss at step 32000: 3.414361
# Average loss at step 34000: 3.444739
# Average loss at step 36000: 3.367227
# Average loss at step 38000: 3.491789
# Average loss at step 40000: 3.448827
# Nearest to an: devoiced, legion, millennia, the, overuse, torre, betrothal, beersheba,
# Nearest to would: will, can, may, could, must, should, might, cannot,
# Nearest to time: rodent, way, period, preparation, years, maxi, year, chekhov,
# Nearest to system: systems, magnet, effects, tulare, minsky, vatican, devices, skywalker,
# Nearest to such: known, well, these, regarded, prosperity, daphne, further, many,
# Nearest to not: still, it, they, always, usually, now, almost, fenced,
# Nearest to his: their, her, its, the, s, weu, our, stepped,
# Nearest to over: full, positive, through, featuring, skulls, around, niagara, algernon,
# Nearest to also: now, which, still, often, never, hilly, sometimes, cleves,
# Nearest to when: if, although, before, while, where, however, after, blurring,
# Nearest to a: any, the, resistances, another, propagandist, fayed, hugh, disputing,
# Nearest to than: or, much, scissors, rafe, errol, centric, antecedents, bead,
# Nearest to use: amount, end, descending, form, orchid, fountains, compensated, results,
# Nearest to this: which, it, that, the, some, what, another, any,
# Nearest to as: phoca, masculism, smiles, quantization, harmonicas, moqed, rolled, christoph,
# Nearest to more: less, very, most, larger, longer, other, highly, ucr,
# Average loss at step 42000: 3.433149
# Average loss at step 44000: 3.281758
# Average loss at step 46000: 3.409583
# Average loss at step 48000: 3.431943
# Average loss at step 50000: 3.438216
# Nearest to an: devoiced, legion, animator, redefining, millennia, dien, observing, chroniclers,
# Nearest to would: will, could, can, may, must, should, might, cannot,
# Nearest to time: day, period, way, year, preparation, rodent, freeview, disorders,
# Nearest to system: systems, magnet, devices, tulare, fresno, bova, phalanx, rents,
# Nearest to such: well, known, regarded, these, seen, cheeses, certain, hvac,
# Nearest to not: still, always, hayes, they, never, merseyside, generally, actually,
# Nearest to his: her, their, its, our, my, the, pectin, professes,
# Nearest to over: through, full, around, skulls, positive, antiprism, montage, reeds,
# Nearest to also: now, often, still, which, sometimes, usually, never, generally,
# Nearest to when: if, although, before, after, while, where, during, blurring,
# Nearest to a: another, the, any, raison, fayed, hugh, accidents, teleplay,
# Nearest to than: or, much, considerably, centric, antecedents, scissors, bead, asb,
# Nearest to use: amount, end, form, descending, fountains, orchid, advantage, cause,
# Nearest to this: which, it, that, some, what, the, another, durango,
# Nearest to as: smiles, leak, phoca, investments, symmes, harmala, contaminants, before,
# Nearest to more: less, most, very, larger, longer, extremely, scottie, gutierrez,
# Average loss at step 52000: 3.455429
# Average loss at step 54000: 3.428767
# Average loss at step 56000: 3.402204
# Average loss at step 58000: 3.287018
# Average loss at step 60000: 3.385060
# Nearest to an: devoiced, millennia, followings, legion, birka, irreducible, kilns, torre,
# Nearest to would: could, will, can, must, should, may, might, cannot,
# Nearest to time: year, period, preparation, day, way, maxi, actinidia, label,
# Nearest to system: systems, tulare, devices, reality, magnet, rents, effects, competent,
# Nearest to such: well, known, these, regarded, many, including, cheeses, hvac,
# Nearest to not: still, almost, actually, never, always, only, merseyside, it,
# Nearest to his: her, their, its, my, the, our, your, woodrow,
# Nearest to over: around, through, full, skulls, positive, about, lamenting, antiprism,
# Nearest to also: which, now, still, often, who, never, generally, sometimes,
# Nearest to when: if, before, although, after, where, while, though, however,
# Nearest to a: another, teleplay, the, transcribed, raison, fayed, preoccupation, slovaks,
# Nearest to than: or, much, considerably, posteriori, asb, lotus, scissors, antecedents,
# Nearest to use: cause, form, end, amount, fountains, advantage, topple, presence,
# Nearest to this: which, it, that, what, another, similar, the, some,
# Nearest to as: masculism, serials, cherbourg, byzantium, became, smiles, mercosur, myers,
# Nearest to more: less, most, very, larger, highly, rather, gutierrez, extremely,
# Average loss at step 62000: 3.439411
# Average loss at step 64000: 3.361515
# Average loss at step 66000: 3.340574
# Average loss at step 68000: 3.388968
# Average loss at step 70000: 3.371898
# Nearest to an: devoiced, legion, another, redefining, kilns, birka, pleasing, ronaldo,
# Nearest to would: could, will, can, should, must, may, might, cannot,
# Nearest to time: day, year, period, preparation, way, malinche, assimilate, queensberry,
# Nearest to system: systems, phalanx, devices, rents, magnet, tulare, inteligencia, effects,
# Nearest to such: well, these, known, regarded, many, some, certain, cheeses,
# Nearest to not: never, almost, generally, they, actually, always, still, now,
# Nearest to his: her, their, its, my, our, the, your, s,
# Nearest to over: around, skulls, full, through, topper, demographic, across, antiprism,
# Nearest to also: now, still, which, never, often, sometimes, actually, who,
# Nearest to when: if, although, before, after, where, while, though, thus,
# Nearest to a: another, activation, any, the, raison, preoccupation, chapels, teleplay,
# Nearest to than: or, much, considerably, vocally, asb, vertebrae, scissors, posteriori,
# Nearest to use: form, cause, amount, end, advantage, presence, fountains, list,
# Nearest to this: which, it, another, the, excel, raspberry, lockout, elbridge,
# Nearest to as: phoca, smiles, mercosur, like, by, masculism, moqed, cali,
# Nearest to more: less, very, most, larger, highly, longer, better, frelimo,
# Average loss at step 72000: 3.400443
# Average loss at step 74000: 3.387441
# Average loss at step 76000: 3.354491
# Average loss at step 78000: 3.239787
# Average loss at step 80000: 3.375440
# Nearest to an: the, millennia, devoiced, redefining, borden, qazaqstan, birka, legion,
# Nearest to would: will, could, can, may, should, must, might, cannot,
# Nearest to time: day, period, year, way, preparation, archangels, label, dispensed,
# Nearest to system: systems, tulare, phalanx, rents, magnet, vatican, devices, protector,
# Nearest to such: well, these, known, regarded, including, certain, many, slid,
# Nearest to not: never, actually, almost, always, fenced, they, still, generally,
# Nearest to his: her, their, its, your, my, our, the, stepped,
# Nearest to over: around, full, through, skulls, montage, topper, positive, antiprism,
# Nearest to also: often, now, still, which, sometimes, never, actually, usually,
# Nearest to when: if, although, though, where, while, before, after, thus,
# Nearest to a: another, any, the, accidents, unforgiven, every, propagandist, activation,
# Nearest to than: or, much, considerably, asb, vertebrae, vocally, remarkable, scissors,
# Nearest to use: cause, form, amount, end, presence, list, advantage, exception,
# Nearest to this: which, it, the, another, some, what, similar, that,
# Nearest to as: masculism, moqed, when, bbb, cali, caprino, by, scenery,
# Nearest to more: less, most, very, larger, better, highly, longer, frelimo,
# Average loss at step 82000: 3.301860
# Average loss at step 84000: 3.338753
# Average loss at step 86000: 3.344713
# Average loss at step 88000: 3.320084
# Average loss at step 90000: 3.243924
# Nearest to an: devoiced, birka, minesweeper, overuse, legion, another, redefining, contracting,
# Nearest to would: could, will, can, should, must, may, might, cannot,
# Nearest to time: day, period, way, daoud, year, repel, clinching, place,
# Nearest to system: systems, rents, tulare, reality, phalanx, devices, inteligencia, protector,
# Nearest to such: well, known, regarded, certain, these, seen, many, served,
# Nearest to not: never, almost, still, actually, remarque, now, always, generally,
# Nearest to his: her, their, its, my, your, our, the, s,
# Nearest to over: around, full, topper, skulls, through, miles, staggered, montage,
# Nearest to also: which, never, still, now, often, sometimes, who, actually,
# Nearest to when: if, before, after, where, although, while, though, then,
# Nearest to a: another, the, raison, chapels, slovaks, mafia, footnotes, plum,
# Nearest to than: or, much, considerably, asb, gto, nola, centric, vocally,
# Nearest to use: cause, cistercian, exasperation, bead, amount, unceasing, coney, list,
# Nearest to this: which, it, another, some, that, the, each, culminating,
# Nearest to as: smiles, cali, mercosur, bedrooms, hampden, became, scenery, psychotherapist,
# Nearest to more: less, very, larger, most, longer, better, highly, gutierrez,
# Average loss at step 92000: 2.737025
# Average loss at step 94000: 3.107517
# Average loss at step 96000: 3.069782
# Average loss at step 98000: 3.220329
# Average loss at step 100000: 3.282645
# Nearest to an: another, devoiced, pleasing, animator, cistercian, legion, vested, cyc,
# Nearest to would: could, will, can, must, should, may, might, cannot,
# Nearest to time: day, period, year, way, queensberry, name, preparation, actinidia,
# Nearest to system: systems, rents, tulare, tlatelolco, protector, devices, reality, schafer,
# Nearest to such: well, known, these, regarded, certain, many, including, cheeses,
# Nearest to not: never, still, now, almost, actually, remarque, fenced, generally,
# Nearest to his: her, their, its, my, your, s, these, our,
# Nearest to over: through, around, skulls, off, topper, equinox, full, balts,
# Nearest to also: often, still, never, now, sometimes, always, actually, which,
# Nearest to when: if, before, where, after, though, although, while, because,
# Nearest to a: the, another, any, every, raison, activation, fayed, enough,
# Nearest to than: or, much, considerably, nola, asb, gto, marketplace, vocally,
# Nearest to use: cause, amount, exception, presence, usage, list, cistercian, bead,
# Nearest to this: which, another, it, what, the, that, some, there,
# Nearest to as: bedrooms, smiles, bbb, mercosur, tinymud, townspeople, phoca, gaucho,
# Nearest to more: less, most, very, larger, longer, rather, fairly, greater,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
